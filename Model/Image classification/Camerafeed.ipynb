# %%
from tensorflow.keras.models import load_model
import os
import cv2
import numpy as np
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.applications.mobilenet_v2 import decode_predictions

# %%
model = newModel = load_model(os.path.join('Model', 'imageclassification.h5'))

# %%
# Start capturing video from the MacBook camera
cap = cv2.VideoCapture(0)

# Define class labels (replace with your actual class labels)
class_labels = ["Windows", "Macbook"]

while True:
    # Capture frame-by-frame
    ret, frame = cap.read()

    # Check if frame is empty
    # Preprocess the frame
    
    resized_frame = cv2.resize(frame, (256, 256))
    img_array = image.img_to_array(resized_frame)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = preprocess_input(img_array)

    # Make predictions
    predictions = model.predict(img_array)
    if predictions >= .5:
        predicted_class_index=0
    elif predictions <.5:
        predicted_class_index=1
    #predicted_class_index = np.argmax(predictions)  # Get the index of the predicted class
    predicted_class = class_labels[predicted_class_index]  # Get the predicted class label
    # Draw predicted class label on the frame
    cv2.putText(frame, predicted_class, (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 0), 2)

    # Display the frame with predictions
    cv2.imshow('Camera Feed', frame)

    # Break the loop if 'q' is pressed


# Release the camera and close all OpenCV windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 2024-11-25 13:42:01.562 python[29116:1967021] WARNING: AVCaptureDeviceTypeExternal is deprecated for Continuity Cameras. Please use AVCaptureDeviceTypeContinuityCamera and add NSCameraUseContinuityCameraDeviceType to your Info.plist.
# ...
# 1/1 [==============================] - 0s 12ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 20
#      17 img_array = preprocess_input(img_array)
#      19 # Make predictions
# ---> 20 predictions = model.predict(img_array)
#      21 if predictions >= .5:
#      22     predicted_class_index=0
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
# ...

# %%
predicted_class
# Out:
# 'Macbook'

# %%
model.predict(img_array)
# Out:
# 1/1 [==============================] - 0s 16ms/step
# array([[3.96935e-20]], dtype=float32)

# %%
predicted_class_index
# Out:
# 1
